# %% [markdown]
# #**Google Play Store Market Performance Analysis**

# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Bussines Understanding**

# %% [markdown]
# ##**Bussines Objective**

# %% [markdown]
# Dataset Google Play Store Apps
#
# Dateset ini merupakan kumpulan data yang berisi informasi mengenai berbagai macam aplikasi yang tersedian pada platform Google Play Store Apps. Data yang ada didalam dataset ini mencangkup atribut-atribut penting seperti kategori aplikasi, rating pengguna, review pengguna, size aplikasi, jumlah unduhan, jenis aplikasi, rating konten, jenis genre, harga, tanggal update terbaru aplikasi, dan detail versi dari aplikasi.
#
# Persaingan antar pengembang semakin bertingkat seiring dengan bertambahnya jumlah aplikasi yang tersedia. Sangat penting bagi pengembang maupun perusahaan pengembang untuk bisa memahami faktor-faktor apa saja yang dapat mempengaruhi keberhasilan suatu aplikasi. Data dari dataset aplikasi Google Play Store ini, akan sangat berguna untuk pengembang aplikasi maupun perusahaan pengembang dalam mengembangkan aplikasi dan menguasai pasar. Biasanya, keberhasilan suatu aplikasi dapat diukur melalui rating pengguna, review pengguna, jumlah pengguna yang menginstal aplikasi, dan tingkat popularitas.
#
# Tujuan bisnis dari analisis aplikasi ini adalah meningkatkan daya saing produk aplikasi di pasar digial yang kompetitif dengan memahami faktor-faktor apa saja yang mempengaruhi performa dan keberhasilan suatu produk aplikasi.
#
# Selain itu, tujuan bisnis dari analisis ini juga untuk meningkatkan kepuasan serta loyalitas pengguna, mengoptimalkan strategi untuk pengembangan aplikasi, meningkatkan popularitas serta jumlah pengguna aplikasi, dan juga mengoptimalkan monetisasi yang ada pada aplikasi.

# %% [markdown]
# ##**Assess Situation**

# %% [markdown]
# Situasi dari dataset ini menggambarkan kondisi aplikasi Google Play Store yang berskala global. Seiring berjalannya waktu, aplikasi ini terus berkembang pesat dengan meningkatnya pengguna aplikasi pada perangkat smartphone di berbagai belahan dunia. Kondisi ini tentunya menyebabkan persaingan antar pengembang aplikasi dan perusahaan pengembang semakin ketat dari segi kualitas maupun inovasi sebuah aplikasi.
#
# Pasar aplikasi mobile yang dinamis disebabkan oleh kebutuhan pengguna yang berbeda-beda dan terus berubah dengan cepat. Oleh karena itu, pengembang maupun perusahaan pengembang aplikasi harus memiliki pemahaman dan analisis yang mendalam mengenai kebutuhan pengguna serta perilaku pengguna agar mampu mempertahankan daya saing di pasar global dan memperoleh insight yang dibutuhkan. Melalui insight tersebut, perusahaan dapat mengambil keputusan, seperti pengembangan fitur-fitur yang ada pada aplikasi, menentukan model bisnis, serta dapat merancang strategi bisnis yang tepat dan efektif.

# %% [markdown]
# ##**Analytic Goals**

# %% [markdown]
# Berdasarkan kondisi yang ada pada dataset serta kebutuhan pengembang aplikasi maupun perusahaan pengembang dalam memahami preferensi pengguna, akan dilakukan:
#
# *   Melakukan indentifikasi tren dan pola penggunaan aplikasi.
# *   Melakukan analisis faktor-faktor yang memperngaruhi popularitas suatu aplikasi.
# *   Melakukan analisis perbandingan performa aplikasi gratis dan aplikasi berbayar dalam hal popularitas dan kepuasaan pengguna.
# *   Menghasilkan rekomendasi berbasis data yang dapat membantu pengembang aplikasi maupun perusahaan pengembang untuk meningkatkan kualitas aplikasi.

# %% [markdown]
# ##**Project Plan**

# %% [markdown]
# Berdasarkan tujuan dari analisis bisnis, akan dilakukan beberapa tahapan berikut:
#
#
# *   Mempelajari struktur dataset untuk memeperoleh gambaran awal sebelum mengolah data.
# *   Melakukan pengolahan dan pembersihan data sebelum melakukan analisis lebih lanjut.
# *   Melakukan analisis data lebih lanjut untuk menemukan insight yang relevan dengan tujuan dan kebutuhan bisnis.
# *   Menghasilkan visualisasi data yang informatif.
# *   Menyusun insight dan rekomendasi strategis sebagai pendukung dasar dalam pengambilan keputusan bisnis.

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ##**Memuat Dataset**

# %% [markdown]
# Sumber dataset ini berasal dari data aplikasi yang tersedia di aplikasi Google Play Store. Dataset ini digunakan untuk menganalisis performa aplikasi, tren kategori aplikasi populer, serta faktor-faktor yang memengaruhi tingkat popularitas dan penilaian aplikasi di Google Play Store.

# %%
file = "/content/drive/MyDrive/Datasets/googleplaystore.csv"
df = pd.read_csv(file)

df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# ## **Deskripsi Data**

# %% [markdown]
# ### **Informasi Dasar**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# Berdasarkan data yang ada di atas, dataset dari aplikasi Google Play Store ini memiliki 10841 Baris dan 13 Kolom.

# %% [markdown]
# ### **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# 1.   App:
#         * Jumlah baris: 10841
#         * Tipe data: object
#         * Deskripsi: Nama aplikasi yang tersedia di Google Play Store.
#
# 2.   Category:
#         * Jumlah baris: 10841
#         * Tipe data: object
#         * Deskripsi: Kategori aplikasi yang ada pada Google Play Store, seperti Game, Business, Education, dsb.
#
# 3.   Rating:
#         * Jumlah baris: 9367
#         * Tipe data: float64
#         * Deskripsi: Nilai rating aplikasi yang diberikan oleh pengguna dengan skala 1 sampai 5.
#
# 4.   Reviews:
#         * Jumlah baris: 10841
#         * Tipe data: object
#         * Deskripsi: Jumlah ulasan yang diberikan oleh pengguna.
#
# 5.   Size:
#         * Jumlah baris: 10841
#         * Tipe data: object
#         * Deskripsi: Ukuran aplikasi dalam MB atau KB.
#
# 6.   Installs:
#         * Jumlah baris: 10841
#         * Tipe data: object
#         * Deskripsi: Jumlah total unduhan aplikasi.
#
# 7.   Type:
#         * Jumlah baris: 10840
#         * Tipe data: object
#         * Deskripsi: Tipe aplikasi, seperti gratis atau berbayar.
#
# 8.   Price:
#         * Jumlah baris: 10841
#         * Tipe data: object
#         * Deskripsi: Harga sebuah aplikasi dalam bentuk dollar ($).
#
# 9.   Content Rating:
#         * Jumlah baris: 10840
#         * Tipe data: object
#         * Deskripsi: Kategori usia pengguna yang ditargetkan, seperti Everyone, Teen, Mature 17+, dsb.
#
# 10.  Genres:
#         * Jumlah baris: 10841
#         * Tipe data: object
#         * Deskripsi: Genre atau sub-kategori aplikasi yang lebih spesifik.
#
# 11.  Last Updated:
#         * Jumlah baris: 10841
#         * Tipe data: object
#         * Deskripsi: Tanggal terakhir aplikasi diperbarui.
#
# 12.  Current Ver:
#         * Jumlah baris: 10833
#         * Tipe data: object
#         * Deskripsi: Versi aplikasi yang paling baru saat ini.
#
# 13.  Android Ver:
#         * Jumlah baris: 10838
#         * Tipe data: object
#         * Deskripsi: Versi minimum Android yang kompatibel untuk menjalankan aplikasi.

# %% [markdown]
# ### **Informasi Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# **1. Count**
#
# Berdasarkan data, total baris aplikasi adalah 10.841. Maka dapat disimpulkan:
#
# * Rating hilang 1.474 data (10.841 - 9.367)
# * Type hilang 1 data (10.841 - 10.840)
# * Content Rating hilang 1 data (10.841 - 10.840)
# * Current Ver hilang 8 data (10.841 - 10.833)
# * Android Ver hilang 3 data (10.841 - 10.838)
#
# Kesimpulan:
#
# Kolom Rating memiliki missing values paling banyak dibandingkan kolom lainnya. Beberapa kolom lain juga mengandung data kosong, namun jumlahnya sangat kecil sehingga tidak terlalu berpengaruh secara keseluruhan. Sebagian besar kolom sudah lengkap (10.841 data).
#
# ---
#
# **2. Mean vs Median**
#
# Karena hanya kolom Rating yang bertipe numerik, maka analisis distribusi difokuskan pada kolom ini.
#
# * Kolom Rating:
#   * Mean = 4,19
#   * Median = 4,30
#
# Perbedaan ini menunjukkan adanya sejumlah aplikasi dengan rating rendah yang menurunkan nilai rata-rata.
#
# Mayoritas aplikasi memiliki rating di atas 4, sehingga secara umum kualitas aplikasi di Google Play Store tergolong baik menurut pengguna.
#
# Kesimpulan:
# Terdapat beberapa nilai rendah yang memengaruhi rata-rata, sementara sebagian besar data terkonsentrasi pada rentang rating yang tinggi (sekitar 4–4,5).
#
# ---
# **3. Min dan Max**
#
# * Rating:
#   * Min = 1,00
#   * Max = 19,00
#
# Kesimpulan:
#
# Nilai minimum 1,00 masih logis karena merupakan batas bawah sistem rating. Namun, nilai maksimum 19,00 tidak sesuai dengan sistem rating Google Play yang seharusnya hanya sampai 5,00.
#
# Hal ini menunjukkan perlunya proses data cleaning sebelum dilakukan analisis lanjutan agar hasil analisis lebih akurat dan valid.
#
# ---
#
# **4. Standar Deviasi (std) – Variabilitas Data**
#
# * Rating
#   * Mean = 4,19
#   * Std = 0,54
#
# Kesimpulan:
#
# Nilai standar deviasi yang relatif kecil dibandingkan rata-ratanya menunjukkan bahwa rating aplikasi tidak terlalu menyebar jauh dari nilai tengahnya. Artinya, sebagian besar aplikasi memiliki rating yang cukup berdekatan, yaitu di sekitar angka 4.
#
# Namun, keberadaan nilai ekstrem 19,00 berpotensi memengaruhi perhitungan statistik dan perlu ditangani melalui proses tahapan data cleaning.

# %% [markdown]
# ## **Verifikasi Kualitas Data**

# %% [markdown]
# ### **Data Type Check**

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# Berdasarkan output diatas, masih terdapat beberapa kolom dengan tipe data yang belum sesuai dan perlu dilakukan penanganan agar analisis statistik dan visualisasi selanjutnya menjadi lebih akurat dan optimal.
#
# Dari output tipe data, hanya kolom Rating yang sudah bertipe data float, sedangkan seluruh kolom lainnya masih bertipe object. Beberapa kolom sebenarnya kurang tepat jika bertipe object, seperti:
#
# * **Reviews** seharusnya bertipe numerik (int), karena berisi jumlah ulasan.
# * **Installs** seharusnya bertipe numerik, karena menunjukkan jumlah unduhan.
# * **Price** seharusnya bertipe numerik (float), karena merepresentasikan harga aplikasi.
# * **Last Updated** seharusnya bertipe date, bukan object, karena berisi tanggal pembaruan aplikasi.

# %% [markdown]
# ### **Incosistent Values**

# %% [markdown]
# **1. Category**
#
# Pada kolom Category ditemukan nilai “1.9” yang tidak sesuai dengan kategori aplikasi. Oleh karena itu, baris tersebut perlu ditangani agar tidak memengaruhi hasil analisis selanjutnya.

# %%
print(df['Category'].unique())
# Out:
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']

# %% [markdown]
# **2. Rating**
#
# Pada kolom Rating ditemukan nilai "19.0" yang melebihi batas maksimum sistem penilaian Google Play, yaitu 5.0. Nilai tersebut menunjukkan adanya kesalahan pada data. Oleh karena itu, data tersebut perlu ditangani agar tidak memengaruhi perhitungan statistik dan hasil analisis.

# %%
print(df['Rating'].unique())
# Out:
# [ 4.1  3.9  4.7  4.5  4.3  4.4  3.8  4.2  4.6  3.2  4.   nan  4.8  4.9
#   3.6  3.7  3.3  3.4  3.5  3.1  5.   2.6  3.   1.9  2.5  2.8  2.7  1.
#   2.9  2.3  2.2  1.7  2.   1.8  2.4  1.6  2.1  1.4  1.5  1.2 19. ]

# %% [markdown]
# **3. Size**
#
# Pada kolom Size ditemukan nilai “Varies with device” yang secara makna valid karena menunjukkan ukuran aplikasi bergantung pada perangkat pengguna. Namun, nilai tersebut berbeda dari format data lainnya seperti “19M” atau “201k”, sehingga perlu diperhatikan jika ingin melakukan analisis lebih lanjut.

# %%
print(df['Size'].unique())
# Out:
# ['19M' '14M' '8.7M' '25M' '2.8M' '5.6M' '29M' '33M' '3.1M' '28M' '12M'
#  '20M' '21M' '37M' '2.7M' '5.5M' '17M' '39M' '31M' '4.2M' '7.0M' '23M'
#  '6.0M' '6.1M' '4.6M' '9.2M' '5.2M' '11M' '24M' 'Varies with device'
#  '9.4M' '15M' '10M' '1.2M' '26M' '8.0M' '7.9M' '56M' '57M' '35M' '54M'
#  '201k' '3.6M' '5.7M' '8.6M' '2.4M' '27M' '2.5M' '16M' '3.4M' '8.9M'
#  '3.9M' '2.9M' '38M' '32M' '5.4M' '18M' '1.1M' '2.2M' '4.5M' '9.8M' '52M'
#  '9.0M' '6.7M' '30M' '2.6M' '7.1M' '3.7M' '22M' '7.4M' '6.4M' '3.2M'
#  '8.2M' '9.9M' '4.9M' '9.5M' '5.0M' '5.9M' '13M' '73M' '6.8M' '3.5M'
#  '4.0M' '2.3M' '7.2M' '2.1M' '42M' '7.3M' '9.1M' '55M' '23k' '6.5M' '1.5M'
#  '7.5M' '51M' '41M' '48M' '8.5M' '46M' '8.3M' '4.3M' '4.7M' '3.3M' '40M'
#  '7.8M' '8.8M' '6.6M' '5.1M' '61M' '66M' '79k' '8.4M' '118k' '44M' '695k'
#  '1.6M' '6.2M' '18k' '53M' '1.4M' '3.0M' '5.8M' '3.8M' '9.6M' '45M' '63M'
#  '49M' '77M' '4.4M' '4.8M' '70M' '6.9M' '9.3M' '10.0M' '8.1M' '36M' '84M'
# ...

# %% [markdown]
# **4. Installs**
#
# Pada kolom Installs ditemukan nilai yang tidak sesuai seperti “Free” yang menunjukkan adanya kesalahan struktur data. Oleh karena itu, data yang tidak valid perlu ditangani agar dapat dilakukan analisis lebih lanjut.

# %%
print(df['Installs'].unique())
# Out:
# ['10,000+' '500,000+' '5,000,000+' '50,000,000+' '100,000+' '50,000+'
#  '1,000,000+' '10,000,000+' '5,000+' '100,000,000+' '1,000,000,000+'
#  '1,000+' '500,000,000+' '50+' '100+' '500+' '10+' '1+' '5+' '0+' '0'
#  'Free']

# %% [markdown]
# **5. Type**
#
# Pada kolom Type ditemukan nilai yang tidak sesuai seperti “0” serta beberapa nilai kosong (NaN). Kolom ini seharusnya hanya berisi dua kategori, yaitu “Free” dan “Paid”. Adanya nilai “0” menunjukkan kemungkinan kesalahan struktur data sehingga perlu ditangani agar analisis perbandingan aplikasi gratis dan berbayar dapat dilakukan secara akurat.

# %%
print(df['Type'].unique())
# Out:
# ['Free' 'Paid' nan '0']

# %% [markdown]
# **6. Price**
#
# Pada kolom Price ditemukan nilai “Everyone” yang bukan merupakan harga aplikasi. Oleh karena itu, perlu dilakukan penanganan agar analisis harga aplikasi dapat dilakukan secara akurat.

# %%
print(df['Price'].unique())
# Out:
# ['0' '$4.99' '$3.99' '$6.99' '$1.49' '$2.99' '$7.99' '$5.99' '$3.49'
#  '$1.99' '$9.99' '$7.49' '$0.99' '$9.00' '$5.49' '$10.00' '$24.99'
#  '$11.99' '$79.99' '$16.99' '$14.99' '$1.00' '$29.99' '$12.99' '$2.49'
#  '$10.99' '$1.50' '$19.99' '$15.99' '$33.99' '$74.99' '$39.99' '$3.95'
#  '$4.49' '$1.70' '$8.99' '$2.00' '$3.88' '$25.99' '$399.99' '$17.99'
#  '$400.00' '$3.02' '$1.76' '$4.84' '$4.77' '$1.61' '$2.50' '$1.59' '$6.49'
#  '$1.29' '$5.00' '$13.99' '$299.99' '$379.99' '$37.99' '$18.99' '$389.99'
#  '$19.90' '$8.49' '$1.75' '$14.00' '$4.85' '$46.99' '$109.99' '$154.99'
#  '$3.08' '$2.59' '$4.80' '$1.96' '$19.40' '$3.90' '$4.59' '$15.46' '$3.04'
#  '$4.29' '$2.60' '$3.28' '$4.60' '$28.99' '$2.95' '$2.90' '$1.97'
#  '$200.00' '$89.99' '$2.56' '$30.99' '$3.61' '$394.99' '$1.26' 'Everyone'
#  '$1.20' '$1.04']

# %% [markdown]
# **7. Genres**
#
# Pada kolom Genres ditemukan nilai yang tidak sesuai seperti tanggal “February 11, 2018” yang menunjukkan adanya data yang tidak valid. Oleh karena itu, data yang tidak valid perlu ditangani dan format genre dapat disesuaikan dengan kebutuhan analisis.

# %%
print(df['Genres'].unique())
# Out:
# ['Art & Design' 'Art & Design;Pretend Play' 'Art & Design;Creativity'
#  'Art & Design;Action & Adventure' 'Auto & Vehicles' 'Beauty'
#  'Books & Reference' 'Business' 'Comics' 'Comics;Creativity'
#  'Communication' 'Dating' 'Education;Education' 'Education'
#  'Education;Creativity' 'Education;Music & Video'
#  'Education;Action & Adventure' 'Education;Pretend Play'
#  'Education;Brain Games' 'Entertainment' 'Entertainment;Music & Video'
#  'Entertainment;Brain Games' 'Entertainment;Creativity' 'Events' 'Finance'
#  'Food & Drink' 'Health & Fitness' 'House & Home' 'Libraries & Demo'
#  'Lifestyle' 'Lifestyle;Pretend Play' 'Adventure;Action & Adventure'
#  'Arcade' 'Casual' 'Card' 'Casual;Pretend Play' 'Action' 'Strategy'
#  'Puzzle' 'Sports' 'Music' 'Word' 'Racing' 'Casual;Creativity'
#  'Casual;Action & Adventure' 'Simulation' 'Adventure' 'Board' 'Trivia'
#  'Role Playing' 'Simulation;Education' 'Action;Action & Adventure'
#  'Casual;Brain Games' 'Simulation;Action & Adventure'
# ...

# %% [markdown]
# **8. Current Ver**
#
# Pada kolom Current Ver ditemukan berbagai format versi aplikasi seperti “1.0”, dan “2.3.4”. Namun, pada dataset terdapat nilai  serta “Varies with device” yang berbeda dari format data lainnya. Oleh karena itu, variasi format yang perlu diperhatikan jika ingin dilakukan analisis lebih lanjut.

# %%
print(df['Current Ver'].unique())
# Out:
# ['1.0.0' '2.0.0' '1.2.4' ... '1.0.612928' '0.3.4' '2.0.148.0']

# %% [markdown]
# **9. Android Ver**
#
# Pada kolom Android Ver ditemukan format versi yang tidak konsisten. Sebagian data menggunakan format minimum versi seperti "4.0.3 and up", sementara sebagian lainnya menggunakan format rentang seperti "4.0.3 - 7.1.1". Selain itu, terdapat nilai "Varies with device" serta beberapa data kosong (NaN). Variasi format data yang ada perlu ditangani agar analisis kompatibilitas aplikasi dapat dilakukan dengan lebih akurat.

# %%
print(df['Android Ver'].unique())
# Out:
# ['4.0.3 and up' '4.2 and up' '4.4 and up' '2.3 and up' '3.0 and up'
#  '4.1 and up' '4.0 and up' '2.3.3 and up' 'Varies with device'
#  '2.2 and up' '5.0 and up' '6.0 and up' '1.6 and up' '1.5 and up'
#  '2.1 and up' '7.0 and up' '5.1 and up' '4.3 and up' '4.0.3 - 7.1.1'
#  '2.0 and up' '3.2 and up' '4.4W and up' '7.1 and up' '7.0 - 7.1.1'
#  '8.0 and up' '5.0 - 8.0' '3.1 and up' '2.0.1 and up' '4.1 - 7.1.1' nan
#  '5.0 - 6.0' '1.0 and up' '2.2 - 7.1.1' '5.0 - 7.1.1']

# %% [markdown]
# ### **Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                 Null Ratio in %
# App                    0.000000
# Category               0.000000
# Rating                13.596532
# Reviews                0.000000
# Size                   0.000000
# Installs               0.000000
# Type                   0.009224
# Price                  0.000000
# Content Rating         0.009224
# Genres                 0.000000
# Last Updated           0.000000
# Current Ver            0.073794
# Android Ver            0.027673

# %% [markdown]
# Berdasarkan output perhitungan rasio nilai kosong terhadap total data, diperoleh insight sebagai berikut:
#
# * Rating
#
#   Kolom Rating memiliki missing values sebesar 13.60%. Persentase ini tergolong cukup signifikan, karena lebih dari 10% data pada kolom tersebut hilang. Hal ini dapat memengaruhi analisis rata-rata rating maupun distribusi penilaian aplikasi. Oleh karena itu, kolom ini perlu ditangani dengan metode yang sesuai tergantung kebutuhan analisis.
#
# * Type
#
#   Kolom Type memiliki missing values sebesar 0.009%. Persentase ini sangat kecil dan tidak terlalu berdampak terhadap keseluruhan analisis. Missing value pada kolom ini dapat ditangani dengan penghapusan baris terkait tanpa memengaruhi hasil analisis secara signifikan.
#
# * Content Rating
#
#   Kolom Content Rating memiliki missing values sebesar 0.009%. Jumlah ini juga sangat kecil sehingga tidak memberikan dampak besar terhadap analisis segmentasi usia pengguna, sehingga data yang hilang dapat ditangani atau dihapus.
#
# * Current Ver
#
#   Kolom Current Ver memiliki missing values sebesar 0.074%. Persentase ini tergolong kecil dan tidak memberikan dampak yang signifikan. Missing value pada kolom ini dapat ditangain lebih lanjut maupun dihapus tanpa memengaruhi analisis secara keseluruhan.
#
# * Android Ver
#
#   Kolom Android Ver memiliki missing values sebesar 0.028%. Jumlah ini juga sangat kecil dan tidak berdampak besar terhadap analisis, sehingga dapat ditangani dengan penghapusan baris terkait.

# %% [markdown]
# ### **Duplicated Values**

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %% [markdown]
# Pada tahap pengecekan data duplikat, ditemukan sebanyak 483 baris yang memiliki nilai terduplikasi dalam dataset. Jumlah ini tergolong cukup signifikan karena dapat memengaruhi hasil analisis, seperti perhitungan rata-rata rating, distribusi kategori aplikasi, maupun jumlah total aplikasi yang tersedia. Keberadaan data duplikat dapat menyebabkan data suatu aplikasi dihitung lebih dari satu kali sehingga menghasilkan insight yang bias. Oleh karena itu, data yang terduplikasi perlu dihapus agar dataset menjadi lebih bersih dan hasil analisis lebih akurat serta representatif.

# %% [markdown]
# ### **Outliers Values**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom   Persentase Outliers
# Rating             4.649018

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Rating'])
plt.title('Boxplot of Rating')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# Berdasarkan output outliers yang ada pada data di atas, kolom Rating memiliki persentase outliers sebesar 4.65%. Outliers yang muncul menunjukkan bahwa nilai tersebut berada di luar pola distribusi mayoritas data, meskipun masih berada dalam rentang skala rating (1–5).
#
# Keberadaan outliers ini kemungkinan berasal dari aplikasi dengan rating yang sangat rendah atau sangat tinggi dibandingkan mayoritas aplikasi lainnya, sehingga lebih mencerminkan variasi penilaian pengguna.
#
# Oleh karena itu, diperlukan pertimbangan lebih lanjut apakah nilai tersebut akan dipertahankan untuk analisis lanjutan atau ditangani, tergantung kebutuhan dan tujuan analisis yang akan dilakukan.

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparison/Perbandingan**

# %% [markdown]
# Aktivitas: Membandingkan rata-rata Rating antara aplikasi dengan tipe gratis dan berbayar.
#
# Tujuan: Mengetahui apakah terdapat perbedaan kualitas aplikasi berdasarkan model bisnisnya, serta mengidentifikasi apakah aplikasi berbayar cenderung memiliki rating lebih tinggi dibandingkan aplikasi gratis.
#
# Visualisasi: Bar Chart (Diagram Batang)

# %%
perbandingan_tipe = df.groupby('Type')['Rating'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=perbandingan_tipe.index, y=perbandingan_tipe.values, palette='viridis', hue=perbandingan_tipe.index, legend=False)
plt.title('Perbandingan Rating Aplikasi Gratis dan Berbayar')
plt.xlabel('Tipe Aplikasi')
plt.ylabel('Rata-rata Rating')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Berdasarkan grafik perbandingan rata-rata rating antara tipe aplikasi gratis dan berbayar, terlihat adanya perbedaan nilai rata-rata rating di antara keduanya. Aplikasi Free (gratis) memiliki rating yang lebih tinggi dari aplikasi Paid (berbayar), hal ini menunjukkan bahwa aplikasi gratis tidak selalu berarti  memiliki kualitas yang lebih rendah. Ternyata banyak aplikasi gratis yang mampu memberikan pengalaman pengguna yang baik meskipun tidak dipungut biaya langsung. Melalui analisis ini, penting untuk memahami persepsi kualitas berdasarkan model monetisasi serta dapat menjadi pertimbangan dalam menentukan strategi bisnis sebuah aplikasi.

# %% [markdown]
# ## **Composition/Komposisi**

# %% [markdown]
# Aktivitas: Menganalisis proporsi jumlah aplikasi pada setiap kategori, khususnya 3 kategori dengan jumlah aplikasi terbanyak.
#
# Tujuan: Mengetahui kategori aplikasi yang paling mendominasi pada aplikasi Google Play Store berdasarkan jumlah aplikasi, sehingga dapat mengidentifikasi indikasi tingginya aktivitas pengembangan dan potensi permintaan pasar.
#
# Visualisasi: Pie Chart (Diagram Lingkaran)

# %%
jumlah_category = df['Category'].value_counts().sort_values(ascending=False)
jumlah_category_top3 = jumlah_category.head(3)

plt.figure(figsize=(10, 8))
jumlah_category_top3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi 3 Kategori Aplikasi Teratas Pada Aplikasi Google Play Store')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# Berdasarkan hasil visualisasi diatas, kategori FAMILY mendominasi dengan 49.8%, diikuti GAME (28.9%) dan TOOLS (21.3%). Hal ini menunjukkan bahwa aplikasi dengan kategori FAMILY paling mendominasi di Google Play Store, yang mengindikasikan tingginya potensi pasar sekaligus tingkat persaingan yang besar. Analisi ini dapat membantu memahami struktur distribusi aplikasi di Google Play Store serta memberikan gambaran mengenai tingkat persaingan dan dinamika pasar pada kategori-kategori populer.

# %% [markdown]
# ## **Distribution/Distribusi**

# %% [markdown]
# Aktivitas: Menganalisis penyebaran nilai Rating pada aplikasi di Google Play Store.
#
# Tujuan: Memahami karakteristik kualitas aplikasi secara umum di Google Play Store berdasarkan rating pengguna, serta mendeteksi adanya ketimpangan distribusi (skewness) atau nilai ekstrem (outlier) yang dapat menunjukkan variasi signifikan dalam kualitas aplikasi.
#
# Visualisasi: Histogram.

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Rating'], bins=30, kde=True)
plt.title('Distribusi Rating Aplikasi di Aplikasi Google Play Store')
plt.xlabel('Rating')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Berdasarkan hasil viasualisasi diatas, terlihat bahwa sebagian besar aplikasi memiliki rating pada rentang 3.5 hingga 4.5, dengan konsentrasi tertinggi berada di sekitar nilai 4.0. Pola ini menunjukkan bahwa mayoritas aplikasi di Google Play Store memperoleh penilaian yang relatif baik dari pengguna. Selain itu, pola distribusi yang menyerupai bentuk lonceng dengan jumlah aplikasi yang sangat sedikit pada rating ekstrem (rendah maupun sangat tinggi), menunjukkan bahwa kualitas aplikasi secara umum berada pada tingkat yang cukup stabil.
#
# Secara keseluruhan, distribusi ini menunjukkan bahwa aplikasi di Google Play Store relatif didominasi oleh aplikasi dengan kualitas yang baik.

# %% [markdown]
# ## **Relationship/Hubungan**

# %% [markdown]
# Aktivitas: Menganalisis hubungan antara jumlah Reviews dan Rating aplikasi.
#
# Tujuan: Mengetahui apakah popularitas suatu aplikasi (berdasarkan banyaknya review) berbanding lurus dengan kualitas aplikasi (rating), serta mengidentifikasi apakah terdapat hubungan antara tingkat interaksi pengguna dan kepuasan pengguna.
#
# Visualisasi: Heatmap.

# %%
# Mengubah tipe data kolom review menjadi numerik
df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')

# Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Rating','Reviews']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')

plt.title('Korelasi antara Rating dan Reviews Pada Google Play Store')
plt.show()

# %% [markdown]
# Berdasarkan hasil visualisasi heatmap diatas, diperoleh nilai korelasi sebesar 0.07 antara kategori Rating dan Reviews. Nilai ini menunjukkan hubungan positif yang sangat lemah dan mendekati nol. Hal ini mengindikasikan bahwa jumlah review yang dimiliki suatu aplikasi tidak memiliki hubungan yang signifikan dengan rating yang diperoleh. Dengan kata lain, banyaknya pengguna yang memberikan ulasan tidak secara langsung menentukan tinggi atau rendahnya penilaian aplikasi tersebut.

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# Berdasarkan hasil eksplorasi awal, tahap ini dilakukan untuk memastikan bahwa dataset berada dalam kondisi yang layak sebelum memasuki proses analisis lebih lanjut. Tahapan ini bertujuan untuk meningkatkan kualitas data dengan memeriksa struktur, konsistensi, serta kelengkapan informasi yang tersedia. Oleh karena itu, data preparation menjadi tahapan penting dalam menjaga validitas dan reliabilitas hasil analisis yang akan dilakukan pada tahapan analisis berikutnya.

# %% [markdown]
# ## **Penanganan Tipe Data**

# %% [markdown]
# Tahapan ini menanganani tipe data, dilakukan penyesuaian terhadap beberapa kolom yang belum sesuai dengan karakteristik informasinya. Ketidaksesuaian tipe data dapat menyebabkan kesalahan dalam proses analisis, seperti saat melakukan perhitungan statistik, visualisasi, maupun pemodelan data. Oleh karena itu, konversi tipe data menjadi langkah penting untuk memastikan bahwa setiap variabel dapat diproses secara optimal.

# %% [markdown]
# **1. Reviews**
#
# Reviews seharusnya bertipe numerik, karena berisi jumlah ulasan. Oleh karena itu, pada tahapan ini tipe data dari kolom Reviews akan di ubah ke tipe data integer.

# %%
# Di ubah ke Numerik
df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')

# %%
# Di ubah ke Integer
df['Reviews'] = df['Reviews'].astype('Int64')

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             Int64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# **2. Installs**
#
# Kolom Installs seharunya bertipe integer, oleh karena itu pada tahapan ini, tipe data dari kolom Installs di ubah ke integer. Namun sebelum itu, karena pada kolom Installs terdapat tanda koma (,) dan simbol (+), maka sebelum di ubah ke numerik dan integer, akan dihilangkan dulu baru bisa di ubah ke numerik dan integer.

# %%
# Menghilangkan tanda (+) dan (,)
df['Installs'] = df['Installs'].str.replace('+', '', regex=False)
df['Installs'] = df['Installs'].str.replace(',', '', regex=False)

# %%
# Diubah ke numerik
df['Installs'] = pd.to_numeric(df['Installs'], errors='coerce')

# %%
# Diubah ke Integer
df['Installs'] = df['Installs'].astype('Int64')

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             Int64
# Size               object
# Installs            Int64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# **3. Price**
#
# Hampir mirip seperti kolom Installs, pada kolom Price seharusnya bertipe data float karena berisi data harga suatu aplikasi. Sebelum di ubah ke dalam tipe data float agar tidak ada data yang hilang (NaN) maka simbol dollar ($) akan dihilangkan terlebih dahulu baru di ubah ke numerik dan float.

# %%
# Menghilangkan simbol dollar ($)
df['Price'] = df['Price'].str.replace('$', '', regex=False)

# %%
# Di ubah ke Numerik
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# %%
# Di ubah ke Float
df['Price'] = df['Price'].astype('Float64')

# %%
df.dtypes # After di Perbaiki
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             Int64
# Size               object
# Installs            Int64
# Type               object
# Price             Float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# **4. Last Updated**
#
# pada kolom Last Updated, seharusnya bertipe data datetime karena berisi data tanggal aplikasi terakhir di update. Oleh karena itu, tipe data harus ubah ke datetime. Setelah tipe data di update, otomatis semua  nilai dalam kolom Last Updated menjadi konsisten (formatnya sama semua).

# %%
# Di ubah ke datetime
df['Last Updated'] = pd.to_datetime(df['Last Updated'], errors='coerce')

# %%
df.dtypes # After di Perbaiki
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                    Int64
# Size                      object
# Installs                   Int64
# Type                      object
# Price                    Float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# dtype: object

# %%
# Setelah tipe data di ganti
print(df['Last Updated'].unique())
# Out:
# <DatetimeArray>
# ['2018-01-07 00:00:00', '2018-01-15 00:00:00', '2018-08-01 00:00:00',
#  '2018-06-08 00:00:00', '2018-06-20 00:00:00', '2017-03-26 00:00:00',
#  '2018-04-26 00:00:00', '2018-06-14 00:00:00', '2017-09-20 00:00:00',
#  '2018-07-03 00:00:00',
#  ...
#  '2015-11-23 00:00:00', '2012-06-17 00:00:00', '2015-02-27 00:00:00',
#  '2013-12-18 00:00:00', '2012-02-06 00:00:00', '2014-11-25 00:00:00',
#  '2016-05-19 00:00:00', '2014-01-20 00:00:00', '2014-02-16 00:00:00',
#  '2014-03-23 00:00:00']
# Length: 1378, dtype: datetime64[ns]

# %% [markdown]
# ## **Incosistent Values**

# %% [markdown]
# Pada tahapan ini, semua data yang tidak konsisten akan di lakukan standarisasi agar semua format penulisan sama dan tidak ada yang berbeda.

# %% [markdown]
# **1. Category**
#
# Dapat dilihat, pada kolom Category ditemukan nilai “1.9” yang seharusnya tidak berada pada kolom ini, karena kolom Category hanya berisi jenis atau kategori aplikasi. Keberadaan nilai tersebut menunjukkan adanya ketidakkonsistenan data, yang kemungkinan terjadi akibat kesalahan input atau pergeseran nilai dari kolom lain.

# %%
# Before
print(df['Category'].unique())
# Out:
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']

# %% [markdown]
# Setelah dilakukan pengecekan lebih lanjut, ditemukan bahwa nilai yang tidak sesuai tersebut berada pada baris **10472**. Selain kolom Category, nilai pada kolom lain di baris yang sama juga tidak sesuai dengan format seharusnya. Oleh karena itu, baris 10472 dihapus karena banyak berisi ketidaksesuaian data yang berpotensi memengaruhi hasil analisis.

# %%
# Pengecekan baris dari nilai yang salah
df[df['Category'] == '1.9']
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0     <NA>
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1,000+      <NA>    0   <NA>            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472          NaT  4.0 and up         NaN

# %%
# Menghapus baris 10472
df = df.drop(df[df['Category'] == '1.9'].index)

# %%
# After
print(df['Category'].unique())
# Out:
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']

# %%
# Pengecekan kembali baris dari nilai yang kosong
df[df['Category'] == '1.9']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# **2. Rating**
#
# Pada kolom Rating ditemukan nilai “19.0”, yang jelas-jelas berada di luar batas normal skala rating aplikasi (1–5). Hal ini menunjukkan adanya ketidaksesuaian data dan kemungkinan akibat nilai yang bergeser dari kolom lain.

# %% [markdown]
# Setelah dilakukan pengecekan, nilai tersebut juga berasal dari baris **10472**, yang sebelumnya sudah teridentifikasi bermasalah pada kolom Category. Karena ketidaksesuaian tidak hanya terjadi pada satu kolom, maka baris tersebut dihapus untuk menjaga konsistensi dari kolom Rating.
#
# Baris tidak perlu dihapus lagi karena sudah terhapus pada tahapan sebelumnya. Karena data berada pada baris yang sama, yaitu pada baris **10472**.

# %%
# Pengecekan baris dari nilai yang salah
df[df['Rating'] > 5]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0     <NA>
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1,000+      <NA>    0   <NA>            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472          NaT  4.0 and up         NaN

# %%
# Setelah baris dihapus
print(df['Rating'].unique())
# Out:
# [4.1 3.9 4.7 4.5 4.3 4.4 3.8 4.2 4.6 3.2 4.  nan 4.8 4.9 3.6 3.7 3.3 3.4
#  3.5 3.1 5.  2.6 3.  1.9 2.5 2.8 2.7 1.  2.9 2.3 2.2 1.7 2.  1.8 2.4 1.6
#  2.1 1.4 1.5 1.2]

# %%
# Pengecekan kembali baris dari nilai yang kosong
df[df['Rating'] > 5]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# **3. Size**

# %% [markdown]
# Pada kolom Size ditemukan nilai “Varies with device” yang secara makna masih valid karena menunjukkan ukuran aplikasi yang menyesuaikan perangkat pengguna. Nilai tersebut bukan merupakan kesalahan input. Namun, ditemukan pula nilai “1,000+” yang tidak sesuai dengan format ukuran aplikasi (misalnya “19M” atau “201k”). Nilai tersebut menunjukkan adanya pergeseran data dari kolom lain.

# %%
print(df['Size'].unique())
# Out:
# ['19M' '14M' '8.7M' '25M' '2.8M' '5.6M' '29M' '33M' '3.1M' '28M' '12M'
#  '20M' '21M' '37M' '2.7M' '5.5M' '17M' '39M' '31M' '4.2M' '7.0M' '23M'
#  '6.0M' '6.1M' '4.6M' '9.2M' '5.2M' '11M' '24M' 'Varies with device'
#  '9.4M' '15M' '10M' '1.2M' '26M' '8.0M' '7.9M' '56M' '57M' '35M' '54M'
#  '201k' '3.6M' '5.7M' '8.6M' '2.4M' '27M' '2.5M' '16M' '3.4M' '8.9M'
#  '3.9M' '2.9M' '38M' '32M' '5.4M' '18M' '1.1M' '2.2M' '4.5M' '9.8M' '52M'
#  '9.0M' '6.7M' '30M' '2.6M' '7.1M' '3.7M' '22M' '7.4M' '6.4M' '3.2M'
#  '8.2M' '9.9M' '4.9M' '9.5M' '5.0M' '5.9M' '13M' '73M' '6.8M' '3.5M'
#  '4.0M' '2.3M' '7.2M' '2.1M' '42M' '7.3M' '9.1M' '55M' '23k' '6.5M' '1.5M'
#  '7.5M' '51M' '41M' '48M' '8.5M' '46M' '8.3M' '4.3M' '4.7M' '3.3M' '40M'
#  '7.8M' '8.8M' '6.6M' '5.1M' '61M' '66M' '79k' '8.4M' '118k' '44M' '695k'
#  '1.6M' '6.2M' '18k' '53M' '1.4M' '3.0M' '5.8M' '3.8M' '9.6M' '45M' '63M'
#  '49M' '77M' '4.4M' '4.8M' '70M' '6.9M' '9.3M' '10.0M' '8.1M' '36M' '84M'
# ...

# %% [markdown]
# Setelah dilakukan pengecekan, nilai tidak sesuai tersebut juga terdapat pada baris **10472**. Karena baris ini telah teridentifikasi bermasalah pada beberapa kolom, maka baris tersebut dihapus untuk mencegah bias dalam analisis.
#
# Nilai yang tidak sesuai pada kolom Size, berada dibaris yang sama dengan baris-baris yang sudah ditangani sebelumnya, yaitu baris **10472**. Oleh karena itu, tidak perlu lagi dihapus karena sudah dihapus pada tahap sebelumnya.

# %%
# Pengecekan baris dari nilai yang salah
df[df['Size'] == '1,000+']
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0     <NA>
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1,000+      <NA>    0   <NA>            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472          NaT  4.0 and up         NaN

# %%
# Setelah baris dihapus
print(df['Size'].unique())
# Out:
# ['19M' '14M' '8.7M' '25M' '2.8M' '5.6M' '29M' '33M' '3.1M' '28M' '12M'
#  '20M' '21M' '37M' '2.7M' '5.5M' '17M' '39M' '31M' '4.2M' '7.0M' '23M'
#  '6.0M' '6.1M' '4.6M' '9.2M' '5.2M' '11M' '24M' 'Varies with device'
#  '9.4M' '15M' '10M' '1.2M' '26M' '8.0M' '7.9M' '56M' '57M' '35M' '54M'
#  '201k' '3.6M' '5.7M' '8.6M' '2.4M' '27M' '2.5M' '16M' '3.4M' '8.9M'
#  '3.9M' '2.9M' '38M' '32M' '5.4M' '18M' '1.1M' '2.2M' '4.5M' '9.8M' '52M'
#  '9.0M' '6.7M' '30M' '2.6M' '7.1M' '3.7M' '22M' '7.4M' '6.4M' '3.2M'
#  '8.2M' '9.9M' '4.9M' '9.5M' '5.0M' '5.9M' '13M' '73M' '6.8M' '3.5M'
#  '4.0M' '2.3M' '7.2M' '2.1M' '42M' '7.3M' '9.1M' '55M' '23k' '6.5M' '1.5M'
#  '7.5M' '51M' '41M' '48M' '8.5M' '46M' '8.3M' '4.3M' '4.7M' '3.3M' '40M'
#  '7.8M' '8.8M' '6.6M' '5.1M' '61M' '66M' '79k' '8.4M' '118k' '44M' '695k'
#  '1.6M' '6.2M' '18k' '53M' '1.4M' '3.0M' '5.8M' '3.8M' '9.6M' '45M' '63M'
#  '49M' '77M' '4.4M' '4.8M' '70M' '6.9M' '9.3M' '10.0M' '8.1M' '36M' '84M'
# ...

# %%
# Pengecekan kembali baris dari nilai yang kosong
df[df['Size'] == '1,000+']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# **4. Installs**
#
# Pada kolom Installs, setelah dilakukan perubahan tipe data ke integer, format data menjadi lebih konsisten. Sebelumnya terdapat nilai “Free” yang tidak sesuai karena kolom ini seharusnya berisi jumlah unduhan aplikasi. Nilai yang tidak sesuai tersebut berubah menjadi nilai kosong (NaN) setelah konversi tipe data.
#
# Setelah dilakukan pengecekan, kembali ditemukan bahwa nilai tersebut berasal dari baris **10472**. Oleh karena itu, baris tersebut dihapus karena mengandung ketidaksesuaian pada berbagai kolom.
#
# Nilai yang tidak sesuai pada kolom Installs, berada dibaris yang sama dengan baris-baris yang sudah ditangani sebelumnya, yaitu baris **10472**. Oleh karena itu, tidak perlu lagi dihapus karena sudah dihapus pada tahap sebelumnya.

# %%
# Pengecekan baris dari nilai yang kosong
df[df['Installs'].isna()]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0     <NA>
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1,000+      <NA>    0   <NA>            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472          NaT  4.0 and up         NaN

# %%
# Setelah baris dihapus
print(df['Installs'].unique())
# Out:
# <IntegerArray>
# [     10000,     500000,    5000000,   50000000,     100000,      50000,
#     1000000,   10000000,       5000,  100000000, 1000000000,       1000,
#   500000000,         50,        100,        500,         10,          1,
#           5,          0]
# Length: 20, dtype: Int64

# %%
# Pengecekan kembali baris dari nilai yang kosong
df[df['Installs'].isna()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# **5. Type**
#
# Dapat dilihat, kolom Type seharusnya hanya berisi dua kategori, yaitu “Free” dan “Paid”. Namun ditemukan nilai “0” serta beberapa nilai kosong (NaN) yang tidak sesuai dengan format kategori tersebut. Hal ini mengindikasikan adanya kemungkinan pergeseran nilai dari kolom lain.

# %%
print(df['Type'].unique())
# Out:
# ['Free' 'Paid' nan '0']

# %% [markdown]
# Setelah dilakukan pengecekan, nilai yang tidak sesuai tersebut kembali ditemukan pada baris **10472**. Maka, baris tersebut dihapus karena tidak memenuhi konsistensi data yang diperlukan untuk analisis.
#
# Nilai yang tidak sesuai pada kolom Type, berada dibaris yang sama dengan baris-baris yang sudah ditangani sebelumnya, yaitu baris **10472**. Oleh karena itu, tidak perlu lagi dihapus karena sudah dihapus pada tahap sebelumnya.

# %%
# Pengecekan baris dari nilai yang salah
df[df['Type'] == '0']
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0     <NA>
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1,000+      <NA>    0   <NA>            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472          NaT  4.0 and up         NaN

# %%
# Setelah baris dihapus
print(df['Type'].unique())
# Out:
# ['Free' 'Paid' nan]

# %%
# Pengecekan kembali baris dari nilai yang kosong
df[df['Type'] == '0']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# **6. Price**
#
# Pada kolom Price ditemukan nilai “Everyone” yang tidak sesuai dengan nilai pada kolom Proce, karena kolom ini seharusnya berisi harga aplikasi dalam bentuk numerik. Setelah tipe data diubah menjadi float, nilai tersebut otomatis menjadi NaN (nilai kosong).

# %%
print(df['Price'].unique())
# Out:
# <FloatingArray>
# [   0.0,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,   3.49,
#    1.99,   9.99,   7.49,   0.99,    9.0,   5.49,   10.0,  24.99,  11.99,
#   79.99,  16.99,  14.99,    1.0,  29.99,  12.99,   2.49,  10.99,    1.5,
#   19.99,  15.99,  33.99,  74.99,  39.99,   3.95,   4.49,    1.7,   8.99,
#     2.0,   3.88,  25.99, 399.99,  17.99,  400.0,   3.02,   1.76,   4.84,
#    4.77,   1.61,    2.5,   1.59,   6.49,   1.29,    5.0,  13.99, 299.99,
#  379.99,  37.99,  18.99, 389.99,   19.9,   8.49,   1.75,   14.0,   4.85,
#   46.99, 109.99, 154.99,   3.08,   2.59,    4.8,   1.96,   19.4,    3.9,
#    4.59,  15.46,   3.04,   4.29,    2.6,   3.28,    4.6,  28.99,   2.95,
#     2.9,   1.97,  200.0,  89.99,   2.56,  30.99,   3.61, 394.99,   1.26,
#    <NA>,    1.2,   1.04]
# Length: 93, dtype: Float64

# %% [markdown]
# Setelah dilakukan pengecekan lebih lanjut, nilai yang tidak sesuai tersebut kembali berasal dari baris **10472**. Karena baris ini mengandung berbagai kesalahan format di banyak kolom, maka penghapusan baris dilakukan sebagai langkah pembersihan data.
#
# Namun, tahapan untuk menghapus baris 10472 tidak perlu dilakukan karena sudah dilakukan pada tahapan sebelumnya.

# %%
# Pengecekan baris dari nilai yang kosong
df[df['Price'].isna()]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0     <NA>
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1,000+      <NA>    0   <NA>            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472          NaT  4.0 and up         NaN

# %%
# Setelah baris dihapus
print(df['Price'].unique())
# Out:
# <FloatingArray>
# [   0.0,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,   3.49,
#    1.99,   9.99,   7.49,   0.99,    9.0,   5.49,   10.0,  24.99,  11.99,
#   79.99,  16.99,  14.99,    1.0,  29.99,  12.99,   2.49,  10.99,    1.5,
#   19.99,  15.99,  33.99,  74.99,  39.99,   3.95,   4.49,    1.7,   8.99,
#     2.0,   3.88,  25.99, 399.99,  17.99,  400.0,   3.02,   1.76,   4.84,
#    4.77,   1.61,    2.5,   1.59,   6.49,   1.29,    5.0,  13.99, 299.99,
#  379.99,  37.99,  18.99, 389.99,   19.9,   8.49,   1.75,   14.0,   4.85,
#   46.99, 109.99, 154.99,   3.08,   2.59,    4.8,   1.96,   19.4,    3.9,
#    4.59,  15.46,   3.04,   4.29,    2.6,   3.28,    4.6,  28.99,   2.95,
#     2.9,   1.97,  200.0,  89.99,   2.56,  30.99,   3.61, 394.99,   1.26,
#     1.2,   1.04]
# Length: 92, dtype: Float64

# %%
# Pengecekan kembali baris dari nilai yang kosong
df[df['Price'].isna()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# **7. Genres**
#
# Dapat dilihat lebih jelas, pada kolom Genres ditemukan nilai berupa tanggal “February 11, 2018”, yang jelas tidak sesuai dengan format genre aplikasi. Hal ini menunjukkan adanya pergeseran data antar kolom.

# %%
print(df['Genres'].unique())
# Out:
# ['Art & Design' 'Art & Design;Pretend Play' 'Art & Design;Creativity'
#  'Art & Design;Action & Adventure' 'Auto & Vehicles' 'Beauty'
#  'Books & Reference' 'Business' 'Comics' 'Comics;Creativity'
#  'Communication' 'Dating' 'Education;Education' 'Education'
#  'Education;Creativity' 'Education;Music & Video'
#  'Education;Action & Adventure' 'Education;Pretend Play'
#  'Education;Brain Games' 'Entertainment' 'Entertainment;Music & Video'
#  'Entertainment;Brain Games' 'Entertainment;Creativity' 'Events' 'Finance'
#  'Food & Drink' 'Health & Fitness' 'House & Home' 'Libraries & Demo'
#  'Lifestyle' 'Lifestyle;Pretend Play' 'Adventure;Action & Adventure'
#  'Arcade' 'Casual' 'Card' 'Casual;Pretend Play' 'Action' 'Strategy'
#  'Puzzle' 'Sports' 'Music' 'Word' 'Racing' 'Casual;Creativity'
#  'Casual;Action & Adventure' 'Simulation' 'Adventure' 'Board' 'Trivia'
#  'Role Playing' 'Simulation;Education' 'Action;Action & Adventure'
#  'Casual;Brain Games' 'Simulation;Action & Adventure'
# ...

# %% [markdown]
# Setelah dilakukan pengecekan, nilai tersebut juga terdapat pada baris **10472**. Untuk menjaga konsistensi dan menghindari bias dalam analisis, baris tersebut dihapus dari dataset.
#
# Tahapan untuk menghapus baris 10472 tidak perlu dilakukan lagi karena pada tahapan sebelumnya sudah dilakukan.

# %%
# Pengecekan baris dari nilai yang salah
df[df['Genres'] == 'February 11, 2018']
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0     <NA>
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1,000+      <NA>    0   <NA>            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472          NaT  4.0 and up         NaN

# %%
# Setelah baris dihapus
print(df['Genres'].unique())
# Out:
# ['Art & Design' 'Art & Design;Pretend Play' 'Art & Design;Creativity'
#  'Art & Design;Action & Adventure' 'Auto & Vehicles' 'Beauty'
#  'Books & Reference' 'Business' 'Comics' 'Comics;Creativity'
#  'Communication' 'Dating' 'Education;Education' 'Education'
#  'Education;Creativity' 'Education;Music & Video'
#  'Education;Action & Adventure' 'Education;Pretend Play'
#  'Education;Brain Games' 'Entertainment' 'Entertainment;Music & Video'
#  'Entertainment;Brain Games' 'Entertainment;Creativity' 'Events' 'Finance'
#  'Food & Drink' 'Health & Fitness' 'House & Home' 'Libraries & Demo'
#  'Lifestyle' 'Lifestyle;Pretend Play' 'Adventure;Action & Adventure'
#  'Arcade' 'Casual' 'Card' 'Casual;Pretend Play' 'Action' 'Strategy'
#  'Puzzle' 'Sports' 'Music' 'Word' 'Racing' 'Casual;Creativity'
#  'Casual;Action & Adventure' 'Simulation' 'Adventure' 'Board' 'Trivia'
#  'Role Playing' 'Simulation;Education' 'Action;Action & Adventure'
#  'Casual;Brain Games' 'Simulation;Action & Adventure'
# ...

# %%
# Pengecekan kembali baris dari nilai yang salah
df[df['Genres'] == 'February 11, 2018']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# **8. Current Ver**
#
# Pada kolom Current Ver ditemukan berbagai format versi aplikasi seperti “1.0”, “2.3.4”, serta nilai “Varies with device”. Variasi format ini tidak dikategorikan sebagai kesalahan input, melainkan sebagai representasi versi aplikasi yang memang ditentukan oleh pengembang.
#
# Nilai “Varies with device” menunjukkan bahwa versi aplikasi menyesuaikan dengan perangkat pengguna. Oleh karena itu, nilai tersebut dipertahankan karena masih relevan secara konteks dan tidak termasuk data yang salah.
#
# Karena tujuan analisis bisnis tidak berfokus pada analisis versi aplikasi, maka kolom Current Ver tidak dilakukan visualisasi secara langsung dan hanya akan dipertahankan dalam bentuk aslinya sebagai bagian dari metadata aplikasi.

# %%
print(df['Current Ver'].unique())
# Out:
# ['1.0.0' '2.0.0' '1.2.4' ... '1.0.612928' '0.3.4' '2.0.148.0']

# %% [markdown]
# **9. Android Ver**
#
# Pada kolom Android Ver ditemukan variasi format data, seperti format minimum versi “4.0.3 and up”, format rentang versi “4.0.3 - 7.1.1”, nilai “Varies with device”, serta beberapa data kosong (NaN). Variasi tersebut tidak dikategorikan sebagai kesalahan input.
#
# Oleh karena itu, format “4.0.3 and up” dipertahankan karena menunjukkan batas minimum sistem operasi yang diperlukan. Sementara itu, format rentang seperti “4.0.3 - 7.1.1” menunjukkan adanya batas minimum dan maksimum kompatibilitas sistem operasi, sehingga tetap merepresentasikan informasi yang sah. Nilai “Varies with device” juga dipertahankan karena menunjukkan bahwa kompatibilitas aplikasi bergantung pada spesifikasi perangkat pengguna. Nilai tersebut bukan merupakan kesalahan data, melainkan bentuk metadata yang relevan.
#
# Karena analisis bisnis ini tidak berfokus pada analisis kompatibilitas sistem operasi, kolom Android Ver tidak perlu ditransformasikan ke bentuk numerik. Variasi format yang ada juga tidak memengaruhi analisis utama yang berfokus pada rating, jumlah unduhan, dan karakteristik aplikasi lainnya. Oleh karena itu, kolom ini dapat dipertahankan dalam bentuk aslinya.

# %%
print(df['Android Ver'].unique())
# Out:
# ['4.0.3 and up' '4.2 and up' '4.4 and up' '2.3 and up' '3.0 and up'
#  '4.1 and up' '4.0 and up' '2.3.3 and up' 'Varies with device'
#  '2.2 and up' '5.0 and up' '6.0 and up' '1.6 and up' '1.5 and up'
#  '2.1 and up' '7.0 and up' '5.1 and up' '4.3 and up' '4.0.3 - 7.1.1'
#  '2.0 and up' '3.2 and up' '4.4W and up' '7.1 and up' '7.0 - 7.1.1'
#  '8.0 and up' '5.0 - 8.0' '3.1 and up' '2.0.1 and up' '4.1 - 7.1.1' nan
#  '5.0 - 6.0' '1.0 and up' '2.2 - 7.1.1' '5.0 - 7.1.1']

# %% [markdown]
# ## **Missing Values**

# %% [markdown]
# Berdasarkan output yang ditampilkan, terlihat bahwa terdapat missing values pada kolom Rating, Type, Current Ver, dan Android Ver. Masing-masing kolom memiliki proses penanganan yang berbeda.
#
# Setiap kolom akan ditangani sesuai dengan kondisi dan kebutuhan analisis. Kolom yang masih relevan dengan tujuan analisis bisnis akan dipertimbangkan untuk dilakukan pembersihan data (seperti penghapusan baris atau imputasi), sedangkan kolom yang tidak digunakan secara langsung dalam analisis lanjutan akan dipertimbangkan untuk dihapus menjaga fokus pada variabel yang memiliki nilai informatif lebih tinggi untuk proses analisis.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                 Null Ratio in %
# App                    0.000000
# Category               0.000000
# Rating                13.596532
# Reviews                0.009224
# Size                   0.000000
# Installs               0.009224
# Type                   0.009224
# Price                  0.009224
# Content Rating         0.009224
# Genres                 0.000000
# Last Updated           0.009224
# Current Ver            0.073794
# Android Ver            0.027673

# %% [markdown]
# **1. Rating**
#
# Berdasarkan output diatas, dapat dilihhat kalau kolom rating memiliki missing values sebesar 13%. Jadi kolom tidak perlu di hapus, hanya perlu di imputasi dengan menggunakan median. Selain karena hanya sebesar 13%, kolom Rating dibutuhkan untuk anlisis lebih lanjut.

# %%
df['Rating'] = df['Rating'].fillna(df['Rating'].dropna().median())

# %% [markdown]
# **2. Type**
#
# Pada tahap ini dilakukan pengecekan terhadap kolom Type, yang berisi jenis aplikasi yaitu “Free” dan “Paid”. Ditemukan missing value dengan proporsi sebesar 0.009225% dari keseluruhan data, sehingga jumlahnya sangat kecil dan tidak signifikan.
#
# Karena persentasenya kurang dari 0.01%, maka baris yang berisi nilai kosong pada kolom ini dihapus. Selain itu, setelah dilakukan pengecekan hanya ada satu baris saja yang berisi NaN (missing values). Penanganan ini dilakukan karena penghapusan dalam jumlah yang sangat kecil tidak akan memengaruhi distribusi data maupun hasil analisis secara keseluruhan. Tidak perlu melakukan imputasi (misalnya dengan modus), sehingga struktur kategori tetap sesuai data asli tanpa ada asumsi untuk baris data tersebut.

# %%
# Pengecekan baris dari nilai yang kosong
df[df['Type'].isna()]
# Out:
#                             App Category  Rating  Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN        0  Varies with device
#
#       Installs Type  Price Content Rating    Genres Last Updated  \
# 9148         0  NaN    0.0   Everyone 10+  Strategy   2018-06-28
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
# Menghapus baris dari nilai yang kosong
df = df.dropna(subset=['Type'])

# %% [markdown]
# **3. Current Ver**
#
# Berdasarkan output diatas, kolom Current Ver memiliki missing value sebesar 0.073808%. Persentase ini tergolong sangat kecil dan tidak memberikan dampak yang signifikan.
#
# Namun demikian, kolom Current Ver tidak digunakan dalam analisis lanjutan karena tidak relevan dengan tujuan analisis bisnis. Fokus analisis lebih diarahkan pada variabel yang berkaitan langsung dengan performa dan karakteristik aplikasi seperti Rating, Reviews, Installs, Type, Price, dan Category. Selain itu, data pada kolom ini bersifat kategorikal campuran (format versi aplikasi) sehingga tidak bisa mendukung analisis kuantitatif secara langsung.
#
# Oleh karena itu, kolom Current Ver dihapus dari dataset untuk menyederhanakan proses analisis dan menjaga fokus pada kolom yang memiliki nilai informatif lebih tinggi untuk analisis dan visualisasi lanjutan.

# %%
# Menghapus kolom Current Ver
df = df.drop('Current Ver', axis=1)

# %% [markdown]
# **4. Android Ver**
#
# Berdasarkan output diatas, kolom Android Ver memiliki missing value sebesar 0.018452%, yang juga tergolong sangat kecil dan tidak berpengaruh signifikan terhadap dataset secara keseluruhan.
#
# Meskipun jumlah data yang hilang tidak signifikan, kolom ini juga tidak digunakan dalam tahap analisis berikutnya karena tidak sesuai dengan tujuan analisis bisnis. Kolom Android Ver lebih bersifat metadata mengenai kompatibilitas sistem operasi android, sementara penelitian ini berfokus pada analisis performa dan karakteristik aplikasi di Google Play Store.
#
# Selain itu, data pada kolom ini memiliki format yang bervariasi dan tidak bisa langsung digunakan dalam proses visualisasi lanjutan. Oleh sebab itu, kolom Android Ver dihapus untuk meningkatkan efisiensi proses analisis.

# %%
# Menghapus kolom Android Ver
df = df.drop('Android Ver', axis=1)

# %% [markdown]
# **5. Mengecek Missing Values Kembali**
#
# Setelah dilakukan tahapan-tahapan sebelumnya, setiap kolom sudah tidak memiliki missing values.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %']) # After
# Out:
#                 Null Ratio in %
# App                         0.0
# Category                    0.0
# Rating                      0.0
# Reviews                     0.0
# Size                        0.0
# Installs                    0.0
# Type                        0.0
# Price                       0.0
# Content Rating              0.0
# Genres                      0.0
# Last Updated                0.0

# %% [markdown]
# ## **Duplicated Values**

# %% [markdown]
# Berdasarkan output yang ditampilkan, terdapat 483 baris yang memiliki nilai terduplikasi dalam dataset. Jumlah ini tergolong cukup signifikan karena berpotensi memengaruhi hasil analisis. Keberadaan data duplikat dapat menyebabkan bias dan membuat hasil analisis menjadi kurang akurat.
#
# Oleh karena itu, seluruh baris yang teridentifikasi sebagai duplikat dihapus dari dataset. Langkah ini dilakukan untuk menjaga kualitas dataset, serta meningkatkan validitas hasil analisis pada tahap selanjutnya.

# %%
# Menghapus data yang terduplikat
df = df.drop_duplicates()

# %%
# Setelah data yang terduplikat dihapus
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated]
# Index: []

# %% [markdown]
# ## **Outliers**

# %% [markdown]
# Berdasarkan output yang ditampilkan, terdapat outlier pada kolom **Rating**, **Reviews**, **Installs**, dan **Price**. Awalnya, outliers hanya ada pada kolom Rating. Namun karena telah melewati beberapa tahapan, muncul ouliers pada kolom Reviews, Installs, serta kolom Price. Keempat kolom tersebut merupakan variabel utama dalam analisis sehingga memiliki peran penting dalam proses eksplorasi data maupun tahapan visualisasi data.
#
# Meskipun secara statistik teridentifikasi sebagai outlier, nilai-nilai ekstrem pada kolom tersebut tidak langsung dihapus maupun diimputasi. Hal ini karena nilai yang muncul kemungkinan besar merepresentasikan fenomena nyata di pasar global aplikasi, seperti aplikasi dengan jumlah unduhan sangat tinggi, jumlah ulasan yang besar, harga yang tinggi, maupun perbedaan persepsi pengguna terhadap kualitas aplikasi.
#
# Oleh karena itu, menghapus atau mengganti nilai ekstrem tersebut berpotensi menghilangkan beberapa informasi penting serta mengurangi representasi kondisi real pasar. Dengan demikian, outlier pada keempat kolom tidak ditangani agar analisis tetap mencerminkan distribusi data yang realistis, serta upaya menjaga integritas informasi dalam proses analisis.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom     Persentase Outliers
# Rating               6.981460
# Reviews             18.057165
# Installs            24.777907
# Price                7.387022

# %% [markdown]
# # **Construct Data**

# %% [markdown]
# Pada tahap construct data, dilakukan pembentukan sebuah variabel baru berupa **Kategori Kualitas Aplikasi** berdasarkan Rating dari aplikasi yang ada. Nilai rating awalnya berbentuk numerik (skala 1–5), lalu dikelompokkan ke dalam beberapa kategori seperti Sangat Baik, Cukup Baik, dan Kurang Baik. Pengelompokan ini dilakukan untuk mempermudah interpretasi data serta proses analisis.
#
# Dengan adanya kategori kualitas aplikasi, pola distribusi aplikasi berdasarkan tingkat kepuasan pengguna dapat terlihat dengan jelas.

# %%
def kategori_kualitas(rating):
    if rating >= 4.5:
        return 'Sangat Baik'
    elif rating >= 4.0:
        return 'Cukup Baik'
    else:
        return 'Kurang Baik'

df['Kategori Kualitas Aplikasi'] = df['Rating'].apply(kategori_kualitas)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159   19M     10000  Free    0.0       Everyone
# 1      967   14M    500000  Free    0.0       Everyone
# 2    87510  8.7M   5000000  Free    0.0       Everyone
# 3   215644   25M  50000000  Free    0.0           Teen
# 4      967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres Last Updated Kategori Kualitas Aplikasi
# 0               Art & Design   2018-01-07                 Cukup Baik
# ...

# %% [markdown]
# # **Data Reduction**

# %% [markdown]
# Pada tahap ini, tidak dilakukan pengurangan variabel karena seluruh kolom dalam dataset masih relevan dengan tujuan analisis bisnis.
#
# Setiap variabel memiliki potensi kontribusi dalam menjelaskan pola popularitas (Installs), kepuasan pengguna (Rating dan Reviews), strategi monetisasi (Price dan Type), segmentasi pasar (Category dan Content Rating), serta aspek teknis dan pengembangan (Size dan Last Update).
#
# Oleh karena itu, seluruh variabel dipertahankan untuk menjaga integritas informasi dan mendukung proses eksplorasi data yang lebih mendalam untuk tahapan selanjutnya.

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # **Menyimpan Dataset**

# %%
# menyimpan dataset
df.to_csv('[Bersih]GooglePlayStoreApp.csv', index=False)

# %% [markdown]
# # **Visualisasi**

# %% [markdown]
# Visualiasi data adalah proses menyajikan data atau informasi dalam bentuk visual seperti grafik, chart, maupun diagram. Pada tahapan ini, data yang awalnya berbentuk angka atau tabel yang banyak dan panjang dapat dipahami dengan mudah melalui visualisasi data tersebut. Oleh karena itu, tahapan ini juga penting karena visualisasi data sering digunakan untuk membantu proses analisis serta memudahkan penyampaian informasi dengan lebih jelas dan mudah dipahami.

# %% [markdown]
# ## **Bar Chart**

# %%
top_kategori = df['Category'].value_counts().head(5).sort_values(ascending=False)
data_top_kategori = df[df['Category'].isin(top_kategori.index)]

plt.figure(figsize=(10, 6))
sns.countplot(x='Category', data=data_top_kategori, hue="Kategori Kualitas Aplikasi", palette='viridis', order=top_kategori.index)
plt.title('Perbandingan Aplikasi Berkualitas Tinggi pada 5 Kategori Aplikasi Teratas')
plt.xlabel('Kategori Aplikasi')
plt.ylabel('Jumlah Aplikasi')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Berdasarkan bar chart diatas yang menunjukkan distribusi aplikasi berkualitas tinggi di Google Play Store, terlihat bahwa setiap kategori memiliki jumlah aplikasi berkualitas tinggi yang berbeda. Beberapa kategori memiliki jumlah aplikasi berkualitas tinggi yang lebih banyak dibandingkan kategori lainnya.
#
# Melalui pola tersebut, pihak platform dapat memanfaatkan informasi ini untuk memberikan rekomendasi aplikasi terbaik kepada pengguna serta meningkatkan pemilihan pada kategori dengan kualitas aplikasi yang masih rendah.

# %% [markdown]
# ## **Pie Chart**

# %%
plt.figure(figsize=(10, 6))
plt.pie(df['Type'].value_counts(), labels=df['Type'].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen'])
plt.title('Distribusi Jenis Aplikasi di Google Play Store')
plt.show()

# %% [markdown]
# Berdasarkan pie chart yang menunjukkan distribusi jenis aplikasi di Google Play Store, dapat dilihat bahwa sebagian besar aplikasi yang tersedia merupakan aplikasi gratis dibandingkan dengan aplikasi berbayar.
#
# Melalui pola tersebut, pengembang aplikasi dapat mempertimbangkan strategi monetisasi lain seperti iklan atau pembelian dalam aplikasi untuk tetap memperoleh keuntungan, sementara pihak platform dapat mendukung pengembangan model aplikasi gratis yang tetap berkualitas bagi pengguna.

# %% [markdown]
# ## **Line Chart**

# %%
# Line Chart Berdasarkan Tahun

df['Last Updated'] = pd.to_datetime(df['Last Updated'])

update_per_tahun = df.groupby(df['Last Updated'].dt.year).size()

plt.figure(figsize=(10, 5))
plt.plot(update_per_tahun.index, update_per_tahun.values, marker='o', color='blue')
plt.title('Aktivitas Pembaruan Aplikasi di Google Play Store Berdasarkan Tahun', fontsize=16)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Jumlah Aplikasi yang Diperbarui', fontsize=12)
plt.grid(True)
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan line chart yang menunjukkan aktivitas pembaruan aplikasi di Google Play Store berdasarkan tahun, dapat dilihat bahwa jumlah aplikasi yang diperbarui tidak selalu meningkat secara konsisten setiap tahunnya.
#
# Pada tahun-tahun awal jumlah pembaruan aplikasi masih relatif rendah, bahkan pada tahun 2010–2012 tidak terdapat aktivitas pembaruan aplikasi. Setelah itu jumlah pembaruan mulai meningkat secara bertahap dari tahun 2013 hingga mengalami lonjakan yang cukup signifikan pada tahun-tahun terakhir.
#
# Melalui pola tersebut, pengembang dapat melihat pentingnya melakukan pembaruan aplikasi secara berkala agar aplikasi tetap relevan dan mampu memenuhi kebutuhan pengguna. Selain itu, pihak platform juga dapat mendorong pengembang untuk secara konsisten melakukan pembaruan aplikasi untuk menjaga kualitas, keamanan, dan performa aplikasi yang tersedia di Google Play Store.

# %% [markdown]
# ## **Histogram**

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Rating'], bins=20, kde=True, color='lightblue')
plt.title('Distribusi Rating Aplikasi di Google Play Store')
plt.xlabel('Rating Aplikasi')
plt.ylabel('Jumlah Aplikasi')
plt.show()

# %% [markdown]
# Berdasarkan histogram yang menunjukkan distribusi rating aplikasi di Google Play Store, dapat dilihat bahwa sebagian besar aplikasi memiliki rating yang berada pada rentang nilai yang cukup tinggi. Hal ini menunjukkan bahwa mayoritas aplikasi yang tersedia di platform tersebut memiliki kualitas yang cukup baik berdasarkan penilaian pengguna. Namun, masih terdapat beberapa aplikasi dengan rating yang lebih rendah.
#
# Melalui pola ini, pengembang dapat melakukan evaluasi untuk meningkatkan kualitas aplikasi, sementara pihak platform dapat terus melakukan pemilihan terhadap aplikasi yang memiliki rating rendah agar pengalaman pengguna tetap terjaga.

# %% [markdown]
# ## **Box Plot**

# %%
top_kategori = df['Category'].value_counts().head(5).index
data_top_kategori = df[df['Category'].isin(top_kategori)]

plt.figure(figsize=(12, 7))
sns.boxplot(x='Category', y='Rating', data=data_top_kategori, palette='viridis', order=top_kategori, hue='Category', legend=False)
plt.title('Distribusi Rating Aplikasi pada Top 5 Kategori Aplikasi', fontsize=16)
plt.xlabel('Kategori Aplikasi', fontsize=12)
plt.ylabel('Rating Aplikasi', fontsize=12)
plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan box plot distribusi rating aplikasi pada lima kategori, terlihat bahwa sebagian besar aplikasi memiliki median rating yang relatif tinggi, yaitu berada pada kisaran sekitar 4.2 hingga 4.4.
#
# Selain itu, terlihat adanya beberapa outlier di bawah kuartil 1 yang menunjukkan adanya aplikasi dengan rating jauh lebih rendah dibandingkan mayoritas aplikasi lainnya, serta beberapa outlier di atas kuartil 3 yang menunjukkan adanya aplikasi dengan rating sangat tinggi. Hal ini menunjukkan bahwa meskipun sebagian besar aplikasi memiliki kualitas yang relatif baik, tetap terdapat beberapa aplikasi yang memiliki performa sangat rendah maupun sangat unggul.
#
# Melalui pola ini, aplikasi yang memiliki rating rendah dapat dievaluasi lebih lanjut dengan melihat ulasan pengguna, serta melakukan pengembangan sesuai dengan kebutuhan pengguna. Melalui tahapan tersebut, pengembang dapat meningkatkan kualitas aplikasi sehingga mampu bersaing dengan aplikasi lain yang memiliki rating lebih tinggi.

# %% [markdown]
# ## **ScatterPlot**

# %%
plt.figure(figsize=(9, 6))
plt.scatter(df['Reviews'], df['Installs'], alpha=0.7, color='teal')
plt.title('Relasi Antara Jumlah Reviews dengan Jumlah Instalasi Aplikasi di Google Play Store', fontsize=10)
plt.xlabel('Jumlah Reviews', fontsize=12)
plt.ylabel('Jumlah Installs', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan scatter plot hubungan antara jumlah review dan jumlah instalasi aplikasi di Google Play Store, terlihat bahwa aplikasi dengan jumlah instalasi yang lebih tinggi cenderung memiliki jumlah review yang lebih banyak. Namun, persebaran titik pada grafik terlihat cukup luas sehingga hubungan tersebut tidak terlalu kuat. Hal tersebut menunjukkan bahwa tidak semua pengguna yang mengunduh aplikasi akan memberikan ulasan terhadap aplikasi yang mereka gunakan.
#
# Melalui pola tersebut, pengembang dapat mendorong pengguna untuk memberikan review setelah menggunakan aplikasi, misalnya dengan menampilkan *pop-up* permintaan ulasan di dalam aplikasi atau menyediakan fitur feedback yang mudah diakses. Dengan begitu, informasi mengenai kualitas aplikasi akan semakin lengkap dan dapat membantu calon pengguna lain dalam menentukan pilihan aplikasi yang akan diunduh.

# %% [markdown]
# ## **Heatmap**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Rating', 'Reviews', 'Installs', 'Price']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi Antar Variabel pada Dataset Aplikasi Google Play Store')
plt.show()

# %% [markdown]
# Berdasarkan heatmap yang menunjukkan korelasi antar variabel pada dataset aplikasi Google Play Store, terlihat bahwa jumlah review dan jumlah instalasi memiliki hubungan positif yang cukup kuat, yang berarti bahwa aplikasi yang memiliki jumlah instalasi lebih banyak biasanya juga memiliki jumlah review yang lebih banyak.
#
# Sementara itu, hubungan antara rating dengan variabel lain terlihat lebih lemah, yang berarti banyaknya instalasi atau review tidak selalu menentukan tinggi atau rendahnya rating sebuah aplikasi. Lalu, variabel price juga memiliki korelasi yang sangat rendah dengan variabel lainnya, yang menunjukkan bahwa harga aplikasi tidak terlalu memengaruhi jumlah instalasi maupun jumlah review.
#
# Melalui pola relasi yang ada, pengembang dapat lebih fokus pada peningkatan kualitas dan pengalaman pengguna dibandingkan hanya menentukan harga aplikasi. Selain itu, pengembang juga dapat mendorong pengguna untuk memberikan review agar dapat membantu calon pengguna lain dalam menentukan pilihan aplikasi.
